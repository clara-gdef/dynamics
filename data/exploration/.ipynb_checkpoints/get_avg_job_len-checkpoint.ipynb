# %%
import os
import pickle as pkl
import ipdb
import yaml
from tqdm import tqdm
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-cb3a0c714dba> in <module>
#       4 import yaml
#       5 from tqdm import tqdm
# ----> 6 from scipy.stats import describe
#       7 import numpy as np
#
# ImportError: cannot import name 'describe' from 'scipy.stats' (unknown location)

# %%
global CFG
with open("../../config.yaml", "r") as ymlfile:
    CFG = yaml.load(ymlfile, Loader=yaml.SafeLoader)

# %%
ppl_file = os.path.join(CFG["gpudatadir"], "profiles_jobs_skills_edu_fr_only_TRAIN.pkl")
with open(ppl_file,'rb') as fp:
    data = pkl.load(fp)

# %%
jobs_len = []
for person in tqdm(data):
    for job in person[-1]:
        jobs_len.append(len(job["job"]))
# Out:
# 100%|██████████| 200094/200094 [00:00<00:00, 245623.53it/s]

# %%
import scipy.stats as stats
print(stats.describe(jobs_len))
print(np.percentile(jobs_len, 9))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-d69291a94b27> in <module>
#       1 import scipy.stats as stats
# ----> 2 print(stats.describe(jobs_len))
#       3 print(np.percentile(jobs_len, 9))
#
# AttributeError: module 'scipy.stats' has no attribute 'describe'

# %%
import scipy
